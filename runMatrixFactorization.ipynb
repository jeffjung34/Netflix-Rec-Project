# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Users-Movies Matrix.csv', index_col='User_ID')
ratings = df.values

# %%
def matrix_factorization(R, P, Q, k=5, steps=100, alpha=0.02, beta=0.01, threshold=0.01):
    Q = Q.T
    prev_e = float('inf')
    for step in range(steps):
        for i in range(len(R)):
            for j in range(len(R[i])):
                if R[i][j] > 0:
                    eij = R[i][j] - np.dot(P[i, :], Q[:, j])
                    for r in range(k):
                        P[i][r] += alpha * (2 * eij * Q[r][j] - beta * P[i][r])
                        Q[r][j] += alpha * (2 * eij * P[i][r] - beta * Q[r][j])

        eR = np.dot(P, Q)
        e = 0
        for i in range(len(R)):
            for j in range(len(R[i])):
                if R[i][j] > 0:
                    e += pow(R[i][j] - np.dot(P[i, :], Q[:, j]), 2)
                    for r in range(k):
                        e += (beta / 2) * (pow(P[i][r], 2) + pow(Q[r][j], 2))

        # Check for early stopping
        if step > 0 and abs(prev_e - e) < threshold:
            print(f"Stopping early at step {step}")
            break
        prev_e = e

    return P, Q.T

# %%
'''
n_users = ratings.shape[0]
n_movies = ratings.shape[1]
k = 20  # Number of latent features

np.random.seed(0)
user_matrix = np.random.normal(scale=1./k, size=(n_users, k))
movie_matrix = np.random.normal(scale=1./k, size=(n_movies, k))
'''
# Out:
# '\nn_users = ratings.shape[0]\nn_movies = ratings.shape[1]\nk = 20  # Number of latent features\n\nnp.random.seed(0)\nuser_matrix = np.random.normal(scale=1./k, size=(n_users, k))\nmovie_matrix = np.random.normal(scale=1./k, size=(n_movies, k))\n'

# %%
df_subset = df.head(10) # taking small subset of users to test
ratings_subset = df_subset.values
n_users_subset = ratings_subset.shape[0]  # Number of users in the subset
n_movies = ratings_subset.shape[1]        # Number of movies
k = 5                                    # Number of latent features to extract

np.random.seed(0)
user_matrix_subset = np.random.normal(scale=1./k, size=(n_users_subset, k))
movie_matrix_subset = np.random.normal(scale=1./k, size=(n_movies, k))

# %%
P_subset, Q_subset = matrix_factorization(ratings_subset, user_matrix_subset, movie_matrix_subset, k)

# %%
predicted_ratings_subset = np.dot(P_subset, Q_subset.T)

# %%
movie_titles = df.columns.tolist()
user_id = 6
user_index = df.index.get_loc(user_id)
user_predicted_ratings = predicted_ratings_subset[user_index]

# %%
movies_with_predictions = list(zip(movie_titles, user_predicted_ratings))
sorted_movies_with_predictions = sorted(movies_with_predictions, key=lambda x: x[1], reverse=True)
sorted_movies_with_predictions
# Out:
# [('Beverly Hills Cop', 6.0613805000278),
#  ('Training Day', 5.5781938695078175),
#  ('U.S. Marshals', 5.042218141632069),
#  ('Sixteen Candles', 5.001449160299817),
#  ('Chocolat', 4.941720928671315),
#  ('Joy Ride', 4.903885252620871),
#  ('Three Musketeers', 4.888544294443255),
#  ('Harold and Kumar Go to White Castle', 4.865901935976154),
#  ('Dawn of the Dead', 4.856367991298006),
#  ('The Missing', 4.841239169187098),
#  ('Shanghai Noon', 4.809981803954141),
#  ('Ray', 4.803864434618918),
#  ("Charlotte's Web", 4.802507401458694),
#  ('Hercules', 4.731019843020174),
#  ('Reservoir Dogs', 4.729777786533682),
#  ('The Dead Zone: Season 2', 4.715258152509358),
#  ('Rookie of the Year', 4.687948829341757),
#  ('The Bourne Supremacy', 4.640423116778324),
#  ('The Longest Yard', 4.607753677507673),
#  ('Speed', 4.585863518989189),
#  ("The Wizard of Oz: Collector's Edition", 4.576208211501693),
#  ('Braveheart', 4.574362211356598),
#  ('Free Willy', 4.5682257293103685),
#  ('Bend It Like Beckham', 4.562757420310416),
#  ('Ever After: A Cinderella Story', 4.520364542439153),
#  ('Signs', 4.518792321391249),
#  ('The Godfather', 4.518302139476554),
#  ('Pollyanna', 4.511078274641724),
#  ('Lord of the Rings: The Fellowship of the Ring', 4.496802913578126),
#  ('The Lion King: Special Edition', 4.470265858154908),
#  ('Titan A.E.', 4.454663043777473),
#  ('The Rundown', 4.447055647352849),
#  ('Vampires', 4.440741344645814),
#  ('Dead Man on Campus', 4.407112587927905),
#  ('Ghost', 4.4043438647966395),
#  ('Firefly', 4.380029293985629),
#  ('Not Another Teen Movie', 4.358414585094361),
#  ('Jurassic Park III', 4.323611997633019),
#  ('Men in Black II', 4.321858533872045),
#  ("Footloose: Special Collector's Edition", 4.302237432609345),
#  ('The Mummy', 4.297877100670267),
#  ('Wild Things', 4.296098650565454),
#  ('Children of a Lesser God', 4.287254719557871),
#  ('The Substitute/The Substitute 3', 4.282014726565363),
#  ('Dangerous Minds', 4.271625497958348),
#  ('Superman IV: The Quest for Peace', 4.268833538226935),
#  ('Guarding Tess', 4.253829790042181),
#  ('What the #$*! Do We Know!?', 4.252917558902067),
#  ('In Good Company', 4.247050894987776),
#  ('Smallville: Season 1', 4.234443424014993),
#  ('Rat Race', 4.219193303951042),
#  ('Not Without My Daughter', 4.19536280668322),
#  ('Aimee and Jaguar', 4.169051396616983),
#  ('Silkwood', 4.1378071092882545),
#  ('2 Fast 2 Furious', 4.133701052473608),
#  ('Frida', 4.109234870284708),
#  ('Hook', 4.083368962649396),
#  ('Herbie Rides Again', 4.076389641535763),
#  ('The Faculty', 4.068593676588839),
#  ("Wayne's World", 4.0612866459545796),
#  ('Absolute Power', 4.004459821475194),
#  ('The Recruit', 3.996124913714546),
#  ('Trapped', 3.9819280752657),
#  ("Bram Stoker's Dracula", 3.977205620410725),
#  ('1984', 3.9705749235596453),
#  ('Poltergeist', 3.963640985912063),
#  ('Casino: 10th Anniversary Edition', 3.957904683460288),
#  ('Spirited Away', 3.9525943575091755),
#  ('The Alamo', 3.9501877888311023),
#  ('Ace Ventura: When Nature Calls', 3.945011379556794),
#  ('Where Eagles Dare', 3.939228190273994),
#  ("The Hitchhiker's Guide to the Galaxy", 3.9391010559792403),
#  ('Lilo and Stitch', 3.936041712259532),
#  ('Scooby-Doo 2: Monsters Unleashed', 3.935985737126297),
#  ('War Games', 3.932446354812636),
#  ('Clash of the Titans', 3.930162112384426),
#  ('Il Postino', 3.9235806493268437),
#  ('The American President', 3.9224931934676084),
#  ('Brother Bear (Theatrical Widescreen Version)', 3.920342463552687),
#  ('Elf', 3.9198489163018),
#  ('The Sixth Sense', 3.9177424230437117),
#  ('Under Siege', 3.917683310167898),
#  ('Fear and Loathing in Las Vegas', 3.91323182514672),
#  ('Uprising', 3.9128733984044324),
#  ('The Flintstones', 3.9080592679138686),
#  ("The Devil's Brigade", 3.9067290889310318),
#  ('Man on Fire', 3.9010345390449066),
#  ('A Fistful of Dollars', 3.8993493372174015),
#  ('Sleepy Hollow', 3.8978687196995394),
#  ('Lethal Weapon 3', 3.8963857747741497),
#  ('Shrek 2', 3.887676131231395),
#  ('Escape from Alcatraz', 3.8868178851513226),
#  ('The Ghost and the Darkness', 3.8863289658439912),
#  ('U2: Go Home: Live From Slane Castle', 3.8729498511206217),
#  ('The Seventh Seal', 3.8697828343940786),
#  ('Jade', 3.8680717539459213),
#  ('Seven Brides for Seven Brothers: 50th Anniversary Edition',
#   3.86563893120868),
#  ('Moonstruck', 3.862550219412559),
#  ('The Village', 3.85287950225179),
#  ('Elizabeth', 3.8509657416081566),
#  ('Bad Boys', 3.849930615054762),
#  ('Mean Girls', 3.8461057243200427),
#  ('The People vs. Larry Flynt', 3.845326350881217),
#  ('Scary Movie 2', 3.8438132577217634),
#  ('Life as a House', 3.843419753166158),
#  ('Predator 2', 3.8431078526935543),
#  ('For the Boys', 3.842249202876199),
#  ('Falling Down', 3.8371121216146067),
#  ('The Best Little Whorehouse in Texas', 3.8299414382223262),
#  ('Unleashed', 3.824936588454366),
#  ('Road to Perdition', 3.8182599459593187),
#  ('The Longest Day', 3.8142639284090567),
#  ('Friday Night Lights', 3.806224388848656),
#  ("Cheech & Chong's Up in Smoke", 3.8028914317980953),
#  ('End of Days', 3.802161899712324),
#  ('Time Bandits', 3.7964955371478264),
#  ('From the Earth to the Moon: The Signature Edition', 3.7953300708370588),
#  ('Tales of the City', 3.7886971864995123),
#  ('Just Visiting', 3.784297134109911),
#  ('A Man Apart', 3.784024220186658),
#  ('Planes', 3.7637223843515444),
#  ('The Silence of the Lambs', 3.756781879558388),
#  ('Rudy', 3.7566279318925115),
#  ('The Last Samurai', 3.751504658778071),
#  ('Innerspace', 3.7425436139272503),
#  ('Dragonheart', 3.730882560119448),
#  ('Life or Something Like It', 3.7222632331059033),
#  ('Finding Nemo (Widescreen)', 3.7110270585542695),
#  ('The Scorpion King', 3.698346239349653),
#  ('Mortal Kombat: The Movie', 3.6935596944582123),
#  ('Repo Man', 3.686106525130119),
#  ('Evelyn', 3.6856105090844307),
#  ('Strange Days', 3.685449988987347),
#  ('10 Things I Hate About You', 3.680662867540039),
#  ('Sex and the City: Season 4', 3.674785502536644),
#  ('The Perfect Storm', 3.666969321273404),
#  ('Final Fantasy: The Spirits Within', 3.665584398970795),
#  ('Wrongfully Accused', 3.6654617887417773),
#  ('Tuck Everlasting', 3.664157322957933),
#  ('Rocky V', 3.654893792844812),
#  ('50 First Dates', 3.6509603695356514),
#  ('Flatliners', 3.648233605119443),
#  ('Poison Ivy 2', 3.6301878987308442),
#  ('Forever Young', 3.6293364072864023),
#  ('Universal Soldier', 3.6184796374966806),
#  ('White Squall', 3.6147028677609794),
#  ('Superman: The Movie', 3.610879599237949),
#  ('Disclosure', 3.610017348890715),
#  ('The Bad News Bears', 3.597190351491176),
#  ('Liar Liar', 3.5939800041624306),
#  ('Orgazmo', 3.581944770977695),
#  ('Scream', 3.5772664515073793),
#  ('A Streetcar Named Desire', 3.5755013045756145),
#  ('Masters of the Universe', 3.5726148851654553),
#  ('Gremlins 2: The New Batch', 3.565144277670932),
#  ('No Way Out', 3.549907317950589),
#  ('Dear Frankie', 3.5485401835200205),
#  ('Evolution', 3.5445171122639727),
#  ('For Your Eyes Only', 3.5423328419842535),
#  ("Don't Say a Word", 3.5393228489055217),
#  ("Aliens: Collector's Edition", 3.5376810966732095),
#  ('Serial Mom', 3.5349201852260395),
#  ('Domestic Disturbance', 3.533696802349976),
#  ('The Princess Diaries (Fullscreen)', 3.525487295045843),
#  ('Private Parts', 3.5227197161582993),
#  ('The Pacifier', 3.508676944023022),
#  ('Kill Bill: Vol. 2', 3.5059148424088953),
#  ('Rabbit-Proof Fence', 3.5027823653047845),
#  ('Identity', 3.497832532993364),
#  ('About Schmidt', 3.495164009843228),
#  ('Rambo: First Blood Part II', 3.4892778722239757),
#  ('I Spy', 3.460127220324687),
#  ('Funny Lady', 3.455835502081251),
#  ('Like Water for Chocolate', 3.450624044143543),
#  ('The Passion of the Christ', 3.4449982820288367),
#  ('Original Sin', 3.4439238514448838),
#  ('Sweet November', 3.4332537217377155),
#  ('Dogma', 3.42857220790546),
#  ('Radio Flyer', 3.4160894408348703),
#  ('The English Patient', 3.406325270705061),
#  ('The King and I', 3.3990114145183044),
#  ("Look Who's Talking", 3.3943700192407875),
#  ('Regarding Henry', 3.3893200476438277),
#  ('He Loves Me', 3.385550069640259),
#  ('Cocoon', 3.379822469371622),
#  ('Mutiny on the Bounty', 3.3721262360735333),
#  ('Death Becomes Her', 3.3682074512668687),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',
#   3.3678452647391013),
#  ('Major League', 3.362875933627843),
#  ('Teenage Mutant Ninja Turtles III', 3.3601622285992034),
#  ('The Deer Hunter', 3.3539069055863),
#  ('The West Wing: Season 3', 3.3458461702547573),
#  ('A Cinderella Story', 3.34348524171518),
#  ('Goldfinger', 3.3337458633117167),
#  ('The Sandlot', 3.3233484534480406),
#  ('Southern Comfort', 3.3195200438621884),
#  ('The Game', 3.317640528571212),
#  ('Fletch Lives', 3.297944491870191),
#  ('Hoop Dreams', 3.2911925960511823),
#  ('Better Off Dead', 3.2881290469878315),
#  ('The Addams Family', 3.2865710284530403),
#  ('Air Bud Spikes Back', 3.273196254288154),
#  ('What Women Want', 3.2708736403874177),
#  ('On Golden Pond', 3.2705100865798533),
#  ('Taxi', 3.2684779501353054),
#  ('Super Size Me', 3.2679522668772663),
#  ("The Emperor's New Groove", 3.266909492612308),
#  ('Ghost Ship', 3.2660550458356346),
#  ('American Wedding', 3.2524104111861614),
#  ('Coach Carter', 3.2449351577980243),
#  ('Jimmy Neutron: Boy Genius', 3.2439059196506452),
#  ('The Avengers', 3.241295561395041),
#  ('Serendipity', 3.230044672341185),
#  ('9 1/2 Weeks', 3.1981152594960447),
#  ('Stargate SG-1: Season 8', 3.191756081469358),
#  ('Normal', 3.191219093144589),
#  ('Back to School', 3.189068085427852),
#  ('Patch Adams', 3.185272039359379),
#  ('Aladdin: Platinum Edition', 3.1839309535662395),
#  ('The Door in the Floor', 3.1755337184457004),
#  ('Fallen', 3.17447648665871),
#  ('Along Came Polly', 3.172201744003011),
#  ('Bad Boys II', 3.166141851053164),
#  ('Secondhand Lions', 3.1456846832099545),
#  ('Airplane II: The Sequel', 3.1441946340113263),
#  ('Grumpy Old Men', 3.1419294151315227),
#  ('Mars Attacks!', 3.134081941560469),
#  ('When Harry Met Sally', 3.1325860525712472),
#  ('The Cutting Edge', 3.1300883459574664),
#  ('Chasing Amy', 3.1218946214536425),
#  ('The Sum of All Fears', 3.100412519996339),
#  ('The Mask: Special Edition', 3.0946242971527638),
#  ('While You Were Sleeping', 3.0851174869405753),
#  ('Presumed Innocent', 3.08129331440688),
#  ('Kicking & Screaming', 3.054531184765026),
#  ('One True Thing', 3.0544052331627953),
#  ('Cowboy Bebop Remix', 3.051044418379176),
#  ('The Parent Trap', 3.0399231434000256),
#  ('The Mighty', 3.0382721256062606),
#  ('The Prince of Tides', 3.0377613421611125),
#  ('Back to the Future Part III', 3.0313560271705047),
#  ('First Knight', 3.0310717546114607),
#  ('Bruce Almighty', 3.028352753614125),
#  ('Dragon: The Bruce Lee Story', 3.017762178079271),
#  ("Alien: Resurrection: Collector's Edition", 3.0153687779594986),
#  ('Yu-Gi-Oh!: The Movie', 3.01391047143104),
#  ('Army of Darkness', 3.00790874809617),
#  ('Collateral Damage', 2.993924640768911),
#  ('Hackers', 2.990262123140542),
#  ('The Blues Brothers: Extended Cut', 2.978275132277014),
#  ('An Officer and a Gentleman', 2.9748222094399863),
#  ('About a Boy', 2.969021401479652),
#  ('Dirty Rotten Scoundrels', 2.9654406412655794),
#  ('Batman Begins', 2.958601539643222),
#  ('Exit Wounds', 2.9561302757033308),
#  ('Harlem Nights', 2.954733035954952),
#  ('People I Know', 2.951156319724222),
#  ('The Amityville Horror', 2.948909294166689),
#  ('Hostage', 2.94456723020182),
#  ('Solaris', 2.938113413924517),
#  ('North by Northwest', 2.937510100457054),
#  ('THX 1138: Special Edition', 2.9355993281322053),
#  ('Who Framed Roger Rabbit?: Special Edition', 2.932832539869166),
#  ('The Color of Money', 2.932315546695145),
#  ('Bill Cosby: Himself', 2.927199083926285),
#  ('Ned Kelly', 2.9257400636937247),
#  ("Pink Floyd: Live at Pompeii: Director's Cut", 2.924515648604201),
#  ('Whale Rider', 2.924087708079128),
#  ('Tin Men', 2.920250946605893),
#  ('Bringing Up Baby', 2.9174587635457394),
#  ('The Matrix: Reloaded', 2.9159952804254505),
#  ('Saturday Night Live: The Best of Eddie Murphy', 2.9153969848905086),
#  ('Taking Lives', 2.9122394548079544),
#  ('Murder on the Orient Express', 2.910496207534126),
#  ('Seven Samurai', 2.910246327433009),
#  ('Joe Versus the Volcano', 2.910135570846814),
#  ('Dr. Dolittle 2', 2.909225421129003),
#  ('Finding Neverland', 2.9080821687444103),
#  ('Sleepless in Seattle', 2.9077267813457004),
#  ('Die Hard 2: Die Harder', 2.9065612264608287),
#  ('Sphere', 2.9060233451724766),
#  ('Michael Collins', 2.9032189564553454),
#  ('Heathers', 2.897638614117926),
#  ('The Wedding Planner', 2.896133356339637),
#  ('Curly Sue', 2.8955278849317785),
#  ("Things to Do in Denver When You're Dead", 2.894379012155511),
#  ('First Kid', 2.8942280222748353),
#  ('The Maltese Falcon', 2.8922312263871497),
#  ('Blade: Trinity', 2.8904388889434065),
#  ('Doctor Zhivago', 2.8892581768819623),
#  ('The Hand that Rocks the Cradle', 2.887938537186625),
#  ("Monty Python's The Meaning of Life: Special Edition", 2.8853469260387934),
#  ('The Mothman Prophecies', 2.884770601542903),
#  ("Rosemary's Baby", 2.883140617511636),
#  ('Under Siege 2: Dark Territory', 2.8822750065558354),
#  ('Dinosaur', 2.879316275495381),
#  ("Bridget Jones's Diary", 2.8786026409133174),
#  ("Singin' in the Rain", 2.8784291404675706),
#  ('Clerks', 2.8758451922990123),
#  ('Congo', 2.87216319944378),
#  ('Four Weddings and a Funeral', 2.8687354186528915),
#  ('The Full Monty', 2.868374792333776),
#  ('Beaches', 2.8620302460967504),
#  ('Three Days of the Condor', 2.860661867053665),
#  ('The Grifters', 2.8586960139834487),
#  ('Robin Hood: Prince of Thieves', 2.857784065306351),
#  ('Man of the House', 2.8553857839967223),
#  ('Friends: Season 6', 2.85492355018142),
#  ('The Limey', 2.8546944762639233),
#  ("Something's Gotta Give", 2.850543560323165),
#  ('Going My Way / Holiday Inn', 2.84718974733751),
#  ('Star Trek: The Motion Picture', 2.8424792602885907),
#  ('Cry Freedom', 2.8386726387244123),
#  ('Sleeping Beauty: Special Edition', 2.8384767312473254),
#  ('Y Tu Mama Tambien', 2.835175413704824),
#  ('The Phantom of the Opera: Special Edition', 2.831397761881848),
#  ('History of the World: Part 1', 2.8250772821699583),
#  ('The Matrix: Revolutions', 2.823909712808239),
#  ('The Big Hit', 2.823130080735318),
#  ('The Professional', 2.8177920068907394),
#  ('Love Actually', 2.816467249255834),
#  ('This Is My Father', 2.810423644350177),
#  ('Lethal Weapon', 2.8076073546821463),
#  ("Alien: Collector's Edition", 2.8036879830506036),
#  ('The Pianist', 2.8036728257255406),
#  ('Man on the Moon', 2.802516647995881),
#  ('The Replacement Killers', 2.793041513793202),
#  ("America's Sweethearts", 2.7835150020189867),
#  ('Naked Gun 2 1/2: The Smell of Fear', 2.7787574550316836),
#  ('PCU', 2.772447575133109),
#  ('Spy Kids 2: The Island of Lost Dreams', 2.768592918593492),
#  ("Harrison's Flowers", 2.763582236101735),
#  ('Swimming Pool', 2.7580507808519785),
#  ("Recess: School's Out", 2.7535782411286363),
#  ('The Chorus', 2.75038578260892),
#  ('MASH: Season 7', 2.744363120773282),
#  ('Spartan', 2.7390927062905934),
#  ('Against the Ropes', 2.736722871732749),
#  ('Beyond Borders', 2.736569765880213),
#  ('Ordinary People', 2.720251059377605),
#  ('Silver Streak', 2.719050892113152),
#  ("National Lampoon's Van Wilder", 2.7190286221944757),
#  ('A Beautiful Mind', 2.716691691867508),
#  ('The Day of the Jackal', 2.7128185970041696),
#  ('The Italian Job', 2.7032745844079114),
#  ('Club Dread', 2.696482136482253),
#  ('Sister Act 2: Back in the Habit', 2.6780194377791724),
#  ('Eternal Sunshine of the Spotless Mind', 2.6693567135388223),
#  ('The Vanishing', 2.6597533298004925),
#  ('Planet of the Apes', 2.6152283963199423),
#  ('Damn the Defiant', 2.6128532106015454),
#  ('Spy Kids', 2.6107300370129116),
#  ('Boyz N the Hood', 2.608347687753895),
#  ('Outrageous Fortune', 2.5923925119195297),
#  ('X2: X-Men United', 2.5921751543450684),
#  ('The Motorcycle Diaries', 2.5700378728542055),
#  ('Air Bud: World Pup', 2.567660438364987),
#  ('The Others', 2.564406849053626),
#  ('A Walk in the Clouds', 2.561509739191597),
#  ('State of Grace', 2.5527920830032715),
#  ('House of Sand and Fog', 2.54307249633069),
#  ('Mississippi Burning', 2.5385355389672735),
#  ('So I Married an Axe Murderer', 2.533746517579858),
#  ('The Enforcer', 2.5319332832319037),
#  ('Friends: Season 2', 2.518227249903083),
#  ('Saw', 2.515035521642146),
#  ("Murphy's Romance", 2.509471586169598),
#  ('Nine to Five', 2.4919904668722763),
#  ('Nine Months', 2.4918111897270694),
#  ('BASEketball', 2.4887007446264313),
#  ('Tightrope', 2.4813684118626016),
#  ('Beverly Hills Cop III', 2.453522325387473),
#  ('Hollow Man', 2.4493311522686447),
#  ('The In-Laws', 2.4261086144806576),
#  ('Freaky Friday', 2.4252116169174367),
#  ('Barbershop', 2.4215460758380174),
#  ('The Way We Were', 2.4208689915492503),
#  ('Bowling for Columbine', 2.4193244425440823),
#  ('From Hell', 2.4168487294791006),
#  ('If These Walls Could Talk', 2.3967462094235636),
#  ("101 Dalmatians II: Patch's London Adventure", 2.382558387528513),
#  ('Out for Justice', 2.3707609886220187),
#  ('Scooby-Doo Meets Batman', 2.352884438335801),
#  ('The Last Temptation of Christ', 2.3487316261776883),
#  ('American Psycho', 2.3318521869931748),
#  ('Shoot to Kill', 2.325945042144116),
#  ('Flight of the Navigator', 2.3220338261069084),
#  ('Jaws', 2.3215509328726585),
#  ('Stealing Harvard', 2.3194495687541115),
#  ("Look Who's Talking Too", 2.3118536027956726),
#  ('Confessions of a Teenage Drama Queen', 2.302172461712665),
#  ('The Life Aquatic with Steve Zissou', 2.296586647823079),
#  ('City by the Sea', 2.2897274827273044),
#  ('Strange Brew', 2.2853063901139685),
#  ('Fifteen Minutes', 2.280451575294246),
#  ('Two Mules for Sister Sara', 2.2726407898049437),
#  ('Dr. T & the Women', 2.267484430041543),
#  ('Reindeer Games', 2.26061534503),
#  ('Rose Red', 2.248191324384427),
#  ('Commando', 2.2465353521916067),
#  ('Half Baked', 2.2343067855841854),
#  ('Mystery Men', 2.2315977177485236),
#  ('The Family Man', 2.225643762129026),
#  ('Rising Sun', 2.22439837648333),
#  ('Hidden Agenda', 2.2243217583971),
#  ("Scooby-Doo's Original Mysteries", 2.2202051112106513),
#  ('Here on Earth', 2.2157859180686166),
#  ('Excess Baggage', 2.2084087159942345),
#  ('Armed and Dangerous', 2.2005063885942415),
#  ('Belly of the Beast', 2.185382188736124),
#  ('American Beauty', 2.180595950025697),
#  ('The Fabulous Baker Boys', 2.171505821796895),
#  ('Superstar', 2.1631206681227173),
#  ('The Toy', 2.1376663941754463),
#  ('High Fidelity', 2.077772250163798),
#  ('Cinderella II', 2.060452446179878),
#  ('Indochine', 2.060010333435324),
#  ('The Omen', 2.045938999316711),
#  ('Hocus Pocus', 2.0455208042261943),
#  ('Spun', 2.044805120340175),
#  ('The Importance of Being Earnest', 1.9876984428775957),
#  ('Dracula', 1.9831342575514685),
#  ('Stargate', 1.980950530927897),
#  ('28 Days Later', 1.980270067183699),
#  ('Pumpkin', 1.9735372863737448),
#  ("Buffalo '66", 1.957980055551608),
#  ("The Devil's Own", 1.9550784005588848),
#  ("National Lampoon's Vacation", 1.9536482191093685),
#  ('Surviving Christmas', 1.946272405026174),
#  ('The Pope of Greenwich Village', 1.9350229378194679),
#  ('Missing in Action 2: The Beginning / Missing in Action 3: Braddock',
#   1.912381200631503),
#  ('Fried Green Tomatoes', 1.8960422494824873),
#  ('Bob Roberts', 1.8680019907382295),
#  ('The Sting', 1.8412225751270548),
#  ('Message in a Bottle', 1.8314368278670703),
#  ('Jungle Fever', 1.8269986778033345),
#  ('Around the World in 80 Days', 1.815255846075872),
#  ('To Catch a Thief', 1.8022446555160185),
#  ('Home Alone 2: Lost in New York', 1.7947667073213536),
#  ('Pay It Forward', 1.772789712246551),
#  ('Xena: Warrior Princess: Series Finale', 1.768386604843813),
#  ('Monkey Trouble', 1.7478065482997311),
#  ("Dr. Seuss' The Cat in the Hat", 1.7107564672101188),
#  ('Gentlemen Prefer Blondes', 1.7066264204712636),
#  ("Porky's", 1.6816926246004646),
#  ('The Ladykillers', 1.6793468597810575),
#  ('The Powerpuff Girls Movie', 1.6709797322153561),
#  ('The Apple Dumpling Gang Rides Again', 1.6617101535706449),
#  ('Pocahontas', 1.6419712716295067),
#  ('Undertow', 1.6168900669785768),
#  ('Duplex (Widescreen)', 1.6107240509347194),
#  ('Madeline', 1.6092386116804434),
#  ('Stir Crazy', 1.608222709938568),
#  ('The Wire: Season 1', 1.5836570302896869),
#  ('Igby Goes Down', 1.5820381563326944),
#  ('The Magdalene Sisters', 1.5750312758693983),
#  ('Little Nicky', 1.5322655971521448),
#  ('S.W.A.T.', 1.4972628252631626),
#  ('Live From Baghdad', 1.479821277923395),
#  ('Together', 1.445627444572649),
#  ('The Prime of Miss Jean Brodie', 1.4326143372692666),
#  ('Invasion of the Body Snatchers', 1.413605977043299),
#  ('Play it Again', 1.4119626191371684),
#  ('The Dangerous Lives of Altar Boys', 1.4080022753615324),
#  ('Napoleon Dynamite', 1.4036830048225875),
#  ('Thunderheart', 1.4012098556210115),
#  ('Rush Hour 2', 1.3645469395475969),
#  ('Inspector Gadget 2', 1.3574425598140694),
#  ('The Big One', 1.342034906475196),
#  ('The Cookout', 1.3052006071277416),
#  ('Punchline', 1.3047274556468214),
#  ('Police Academy: Special Edition', 1.2913051599214171),
#  ('The Talented Mr. Ripley', 1.2820000660406097),
#  ('The Pagemaster', 1.2709934101284552),
#  ('The Computer Wore Tennis Shoes', 1.2685712059923753),
#  ('The Legend', 1.2655696206268032),
#  ('Daredevil', 1.2438799347065743),
#  ('Town & Country', 1.2427115461838356),
#  ('Cop and a Half', 1.2405736180912956),
#  ('Nothing to Lose', 1.2058264572755628),
#  ('Rio Lobo', 1.0953584145775435),
#  ('High and Low', 1.0836186741201106),
#  ('The Pledge', 1.0813775036867161),
#  ('Bottle Rocket', 1.061041784006159),
#  ('Garden State', 1.0472532369980792),
#  ('The Incredibly True Adventure of 2 Girls in Love', 1.0354026257460436),
#  ('Buffalo Soldiers', 1.0307645533147598),
#  ('Trigun', 1.0206918571781434),
#  ('Parenthood', 1.0176299200232677),
#  ('Lock', 1.0143621177507915),
#  ('Double Team', 1.0128198963715207),
#  ('The Mark of Zorro', 1.0121583363095492),
#  ('Threesome', 1.0099838788934323),
#  ('The Russians Are Coming', 1.0039532075626567),
#  ('Curb Your Enthusiasm: Season 3', 0.9992379243648274),
#  ('The Simpsons: Season 1', 0.9965452104798089),
#  ('The Quiet Man', 0.9787167106095449),
#  ('Dirty Work', 0.9749492534427081),
#  ('A Nightmare on Elm Street', 0.9733559573635956),
#  ('Woman of the Year', 0.973202007529836),
#  ('Silver Bullet', 0.9725350385061028),
#  ('The Ballad of Jack and Rose', 0.9584333259511677),
#  ('Fame', 0.9558671490536429),
#  ('Six Feet Under: Season 4', 0.9539194563446719),
#  ('Star Trek: Voyager: Season 1', 0.9475814027521124),
#  ('Animal Crackers', 0.9473140631753587),
#  ('Comedian', 0.9457272571912585),
#  ('Operation Pacific', 0.933740049388569),
#  ('Two Can Play That Game', 0.9297460302840939),
#  ('Walkabout', 0.929364006899122),
#  ('Shakes the Clown', 0.9192149861011394),
#  ('Encino Man', 0.917081877445394),
#  ('Saboteur', 0.9129633811674598),
#  ('The Piano', 0.9108776950293513),
#  ('Last Man Standing', 0.9042402211096836),
#  ('The Flying Tigers', 0.9040327668593519),
#  ('Rob Roy', 0.9003562745731754),
#  ('The Muse', 0.8986640755325107),
#  ('Fast', 0.8954758873863186),
#  ('Uncovered: The Whole Truth About the Iraq War', 0.8931683757752261),
#  ("Foyle's War: Set 2", 0.892868358036128),
#  ('Sordid Lives', 0.8913428485512972),
#  ('The Twilight Zone: Vol. 41', 0.8901709210579823),
#  ('City of Ghosts', 0.8868892856174805),
#  ('Abandon', 0.8860443788185107),
#  ('Hudson Hawk', 0.8829370793994276),
#  ('The Little Princess', 0.8785147807515727),
#  ('Candyman 3: Day of the Dead', 0.8738462646766441),
#  ('Monty Python: The Life of Python', 0.8673734348151324),
#  ('The King of Queens: Season 2', 0.8654861101529384),
#  ('A Mighty Wind', 0.8581813496302315),
#  ('The Unsinkable Molly Brown', 0.8531224396779361),
#  ('His Secret Life', 0.84728986290967),
#  ('The Hurricane', 0.839231936109064),
#  ("Dante's Peak", 0.8130108022903976),
#  ('Scandal', 0.8094747610201579),
#  ('A Guy Thing', 0.7991468504183149),
#  ('Party Monster', 0.7925320909951551),
#  ('Home Movie', 0.7904920503850127),
#  ('Gun Shy', 0.7854904330943897),
#  ('Husbands and Wives', 0.7836209213476284),
#  ('Casualties of War', 0.7833646125535332),
#  ('My Neighbor Totoro', 0.7758811198123534),
#  ('Tank Girl', 0.7740181379626985),
#  ('The Blind Swordman: Zatoichi', 0.7722906095171908),
#  ('White', 0.7676404252980806),
#  ('Farinelli', 0.7655945181690074),
#  ('Playing God', 0.7648907714882704),
#  ('Henry V', 0.749001569719531),
#  ('Charade', 0.7478809998064421),
#  ('200 Cigarettes', 0.7420101240650031),
#  ("Michael Moore's The Awful Truth: Season 2", 0.7389938091597064),
#  ('The Secret Garden', 0.7379430360419393),
#  ('This Is Spinal Tap', 0.7371719961713725),
#  ('Dersu Uzala', 0.7321471465133915),
#  ('NYPD Blue: Season 2', 0.7285371953911779),
#  ('Freddy Got Fingered', 0.7265501593758451),
#  ('Friday After Next', 0.7193703011722224),
#  ('Croupier', 0.7188030981415084),
#  ('The Party', 0.7110912278032354),
#  ('A Dirty Shame', 0.7110636426205674),
#  ("Von Ryan's Express", 0.7045515105830338),
#  ('Scorched', 0.7027046271936568),
#  ('All the Right Moves', 0.6940451039445775),
#  ('Samurai Trilogy 3: Duel at Ganryu Island', 0.6928645192466624),
#  ('Ringu', 0.688102207257958),
#  ('Agnes Browne', 0.6879388562252422),
#  ("Rory O'Shea Was Here", 0.6857217818737233),
#  ('Romeo is Bleeding', 0.6776399980610269),
#  ("The Caveman's Valentine", 0.6750509252507394),
#  ('Action Jackson', 0.6747473361133974),
#  ('Irreversible', 0.67445781311931),
#  ('Quicksand', 0.6702164298045077),
#  ('Untamed Heart', 0.6701586084577082),
#  ('Sunshine', 0.6650714854086464),
#  ('Teaching Mrs. Tingle', 0.6635006265321571),
#  ('Undisputed', 0.6557084103192697),
#  ('Starship Troopers 2: Hero of the Federation', 0.654133731634813),
#  ('Annie', 0.6522878186754326),
#  ('Shane', 0.6510691071522094),
#  ('The Caine Mutiny', 0.6509566636130051),
#  ('Like It Is', 0.6425651893219706),
#  ('I Love Lucy: Season 4', 0.6389710403832174),
#  ('Saved by the Bell: Season 1', 0.6364277904767887),
#  ('The Three Stooges: Merry Mavericks', 0.6362337122007696),
#  ('Armageddon', 0.6318959916054366),
#  ("Father's Little Dividend", 0.627835092137789),
#  ("Stephen King's It!", 0.6273739223344728),
#  ("Pooh's Heffalump Movie", 0.6272604678696332),
#  ('Six Degrees of Separation', 0.6255842811290759),
#  ('The Long Walk Home', 0.6217765189820234),
#  ('Fly Away Home', 0.6198231894836354),
#  ('Woman Thou Art Loosed', 0.6124237309524685),
#  ('Impostor', 0.6121554963271014),
#  ('The Thomas Crown Affair', 0.6106282977637136),
#  ('Wallace & Gromit in Three Amazing Adventures', 0.6087760195757375),
#  ('SpongeBob SquarePants: Season 2', 0.6085459581695405),
#  ('Uptown Girls', 0.6067325769331795),
#  ('Wings of Desire', 0.6039255844274976),
#  ('The Opposite of Sex', 0.6032014273308313),
#  ('Me Myself I', 0.602495943836779),
#  ('Tenchi the Movie: Tenchi Muyo! In Love', 0.6021410510811852),
#  ('On the Beach', 0.6011921938642099),
#  ("George Carlin: George's Best Stuff", 0.5879928198415713),
#  ('The Simpsons: Treehouse of Horror', 0.5867595811722374),
#  ('Center Stage', 0.5851040323466135),
#  ('The Simpsons: Bart Wars', 0.5784631537304832),
#  ('The Hunchback of Notre Dame II', 0.5771385398257238),
#  ('Mostly Martha', 0.5757258729341257),
#  ('Sideways', 0.5741099503664212),
#  ('Being John Malkovich', 0.5632748218734377),
#  ('Mr. Magoo', 0.5605094227517008),
#  ('American Psycho 2', 0.5596682540161166),
#  ('Riding Giants', 0.5549195353818159),
#  ('How To Be A Player', 0.5534934986535086),
#  ('Blue Planet: IMAX', 0.5516600009909308),
#  ('The Santa Clause', 0.5498621801565902),
#  ('Midnight Cowboy', 0.5493358148990625),
#  ('Testosterone', 0.5475645606917138),
#  ('Talk Radio', 0.5461636811571922),
#  ('Happiness', 0.53925030131765),
#  ('Behind the Planet of the Apes', 0.5369593034434713),
#  ('The Big Tease', 0.5317225445226248),
#  ('The Ice Storm', 0.5202726014132756),
#  ('Journey to the Center of the Earth', 0.5183678896643154),
#  ('The Lair of the White Worm', 0.5139689090015245),
#  ('Star Trek: The Next Generation: Season 7', 0.5132390116067477),
#  ('The Blob', 0.5106338516664398),
#  ('The Cowboys', 0.5096424239345971),
#  ('Rollerball', 0.5087019564137136),
#  ('Thin Line Between Love & Hate', 0.506222744086652),
#  ('Cries and Whispers', 0.49809870855112454),
#  ('Citizen X', 0.49369346374328127),
#  ('Buying the Cow', 0.4908799760325618),
#  ('Soul Food: Season 1', 0.4904557142821104),
#  ('O Fantasma', 0.48670249864264126),
#  ('Halloween: H2O', 0.48588056139033103),
#  ('Inu-Yasha', 0.484842094082089),
#  ('Rififi', 0.4840525576578683),
#  ('The Night of the Hunter', 0.4826046544679363),
#  ('I Still Know What You Did Last Summer', 0.4825043982028993),
#  ('The Twilight Samurai', 0.48222578301127195),
#  ('Justice League', 0.48173555735791196),
#  ('Annie: Special Anniversary Edition', 0.48032557349357474),
#  ("That '70s Show: Season 1", 0.4795886091239571),
#  ('The Closet', 0.47656270460867767),
#  ('The Last Supper', 0.4727531842902141),
#  ('Disturbing Behavior', 0.4721412272130034),
#  ('Sink the Bismarck', 0.4698675216072966),
#  ('Look at Me', 0.4684065791974115),
#  ('Marty', 0.46824948918271864),
#  ('Character', 0.466879975861661),
#  ('Nicholas Nickleby', 0.46607986617369374),
#  ('Coupling: Season 1', 0.46481951561309715),
#  ('CSI: Season 1', 0.46415122985913676),
#  ('A Christmas Carol', 0.46301610475081223),
#  ('The Life & Death of Peter Sellers', 0.46096710901933957),
#  ('Leprechaun', 0.4557502316368694),
#  ('Battleship Potemkin', 0.45379647899653025),
#  ('Jason and the Argonauts', 0.45354967831118714),
#  ('The Best of Friends: Vol. 4', 0.4451406505198247),
#  ('Defending Your Life', 0.4440871010556208),
#  ('Girls Just Want to Have Fun', 0.44171052483443946),
#  ('Empire Falls', 0.44072744846310186),
#  ('25th Hour', 0.4346542316025731),
#  ("Family Guy: Freakin' Sweet Collection", 0.43130495094233084),
#  ('Halloween II', 0.43097855443186983),
#  ('Amazon Women on the Moon', 0.4305185053458783),
#  ('I Think I Do', 0.4256667879561829),
#  ('Nick of Time', 0.4223844005081382),
#  ('Black Dog', 0.42160679005656615),
#  ('Blue Hawaii', 0.4206452632570769),
#  ('Ararat', 0.42057040398562423),
#  ('The Road to Wellville', 0.41463104893028835),
#  ('Evil Dead 2: Dead by Dawn', 0.4071425445387079),
#  ('All I Wanna Do', 0.4060143510840961),
#  ('The Flintstones in Viva Rock Vegas', 0.40533204752658575),
#  ('Unprecedented: The 2000 Presidential Election', 0.40094305045737677),
#  ("She's Having A Baby", 0.39921119082511264),
#  ('Impromptu', 0.39569192450478785),
#  ('Night and Fog', 0.39314345511700843),
#  ('Wolf', 0.3892852124735762),
#  ('Where the Red Fern Grows', 0.388112242878967),
#  ('An American Rhapsody', 0.38732672566044934),
#  ('Jeff Foxworthy: Totally Committed', 0.38701806365637814),
#  ('Shanghai Triad', 0.3861179474908396),
#  ('Tart', 0.38203235505884925),
#  ('The Mirror Has Two Faces', 0.38097440527863385),
#  ('Bent', 0.37698998830431646),
#  ('Nine Dead Gay Guys', 0.3733884925825217),
#  ('Star Trek: Voyager: Season 5', 0.37146759680218294),
#  ('The Big Red One: Special Edition', 0.37123120170841584),
#  ('At Close Range', 0.3710170409655444),
#  ('Random Hearts', 0.3687905255568445),
#  ('Up at the Villa', 0.3617169663248884),
#  ('The Horse Soldiers', 0.35629268041657103),
#  ('The Stand', 0.3543400868786811),
#  ('Ginger Snaps Back: The Beginning', 0.35251416593847307),
#  ('Dead Ringers', 0.34800885478810323),
#  ('Matewan', 0.34410391533413565),
#  ('Splendor in the Grass', 0.34129819354893565),
#  ('The Trip', 0.3411681675948787),
#  ('Love Potion #9', 0.33925689197334996),
#  ('Tremors 4: The Legend Begins', 0.3384005319075279),
#  ('Left Behind II: Tribulation Force', 0.3383492890247605),
#  ('Ghost in the Shell', 0.32836553981643263),
#  ('Stoked: The Rise and Fall of Gator', 0.32817795095210395),
#  ('Amarcord', 0.3234152936978239),
#  ('The Man Who Knew Too Much', 0.32325994180272366),
#  ('Our Lady of the Assassins', 0.31977650475767716),
#  ('Cousins', 0.3174998845454358),
#  ('Blankman', 0.31615416727225276),
#  ('The Deal', 0.3158896979448065),
#  ('In Living Color: Season 3', 0.3153645784509985),
#  ('Hollywood Shuffle', 0.3150779823233475),
#  ('The Ghost and Mr. Chicken / The Reluctant Astronaut: Double Feature',
#   0.3114465894822243),
#  ('Crazy/Beautiful', 0.3092814542551047),
#  ('Daughter from Danang: American Experience', 0.306594109635581),
#  ('American Pimp', 0.3037684778907619),
#  ('Star Trek: The Next Generation: Season 6', 0.303630083737083),
#  ('Buffy the Vampire Slayer: Season 6', 0.2996068409805622),
#  ('Another Day in Paradise', 0.29901214514666535),
#  ('Conan the Barbarian', 0.2980978389468889),
#  ('The Dead Zone', 0.2976620817055163),
#  ('Young Black Stallion', 0.29544218594054683),
#  ('The Boxer', 0.2898757689060789),
#  ('Hard Eight', 0.2865387936378472),
#  ('Calle 54', 0.2864867286354994),
#  ('The Serpent and the Rainbow', 0.2844048108314687),
#  ('Newsies', 0.28378780713248175),
#  ('The Great Gatsby', 0.28229559538523247),
#  ('2010: The Year We Make Contact', 0.280557693131506),
#  ('Jingle All the Way', 0.27795872056778337),
#  ('Absolutely Fabulous: Series 2', 0.2768133274599574),
#  ('The Twilight Zone: Vol. 42', 0.2718984327810229),
#  ("The Devil's Backbone", 0.26826162488444866),
#  ('Walking Tall', 0.26742946970153103),
#  ('George Carlin: Personal Favorites', 0.2641003946762218),
#  ('The Brothers McMullen', 0.2622561808076967),
#  ('The Fortune Cookie', 0.25728629113186796),
#  ('Gilmore Girls: Season 3', 0.2563354979522083),
#  ('Gilmore Girls: Season 1', 0.25517970199135676),
#  ('The Land Before Time VII: Stone of Cold Fire', 0.2550574032996752),
#  ('Led Zeppelin: The Song Remains the Same', 0.2521450318063947),
#  ('The Twilight Zone: Vol. 27', 0.2516866287803025),
#  ('A Better Tomorrow II', 0.250175541001037),
#  ('Three to Tango', 0.2499387192061745),
#  ('Born Yesterday', 0.2482549671434736),
#  ('Mystery Science Theater 3000: The Wild World of Batwoman',
#   0.2461171584735872),
#  ('Once Bitten', 0.2444946833738308),
#  ('The Final Cut', 0.2431683773961557),
#  ("Scooby-Doo's Spookiest Tales", 0.24269053718084538),
#  ('Brassed Off', 0.23733737158102744),
#  ('Birdman of Alcatraz', 0.22954358839660027),
#  ('The Return', 0.2289447490105448),
#  ('The Shadow', 0.22631821281605918),
#  ('Mafia!', 0.22577682862056855),
#  ('Turbulence', 0.22518546523484473),
#  ('The Librarian: Quest for the Spear', 0.22424010065560057),
#  ('Cradle Will Rock', 0.222287946274567),
#  ('Casper', 0.2219420970535608),
#  ('In Too Deep', 0.21524376019308733),
#  ('The Spanish Prisoner', 0.21488035295291463),
#  ('Bagdad Cafe', 0.21446870461493123),
#  ('My Family', 0.21233575715580186),
#  ('Paper Moon', 0.2121145326903776),
#  ('Bride of Chucky', 0.20848241668196205),
#  ('Saving Grace', 0.20386667780456896),
#  ('Talk to Her', 0.20016259813771217),
#  ('Born Free', 0.1987926389163492),
#  ('Earth Girls Are Easy', 0.19722884770186208),
#  ('The Sleeping Dictionary', 0.19639928847000065),
#  ('George Carlin: Carlin at Carnegie', 0.19271668225785626),
#  ('The L Word: Season 2', 0.19200895918806724),
#  ('Cloak & Dagger', 0.19181818567418213),
#  ('Hellbound: Hellraiser II', 0.19070452369217245),
#  ('The Story of Us', 0.19052687017386874),
#  ('Lonesome Dove', 0.18490317111405888),
#  ("What's Up", 0.1833516361825036),
#  ('Coffee and Cigarettes', 0.18097014362036495),
#  ('Velvet Goldmine', 0.180953872011194),
#  ('Children of the Corn', 0.17910948835177318),
#  ("Pee-Wee's Playhouse: Vol. 1", 0.17797235535276584),
#  ('Scream 3', 0.17706827843480194),
#  ('Extreme Measures', 0.1759057980528866),
#  ('Without a Trace: Season 1', 0.17282607008653383),
#  ('Le Cercle Rouge', 0.17157698300170074),
#  ('Carandiru', 0.17059235527511998),
#  ('The Third Man', 0.1697401645737902),
#  ('The Mouse That Roared', 0.1669932438595957),
#  ('Sense and Sensibility', 0.16650733587604946),
#  ('Code of Silence', 0.1660538731372596),
#  ('The Weather Underground', 0.16489531647800446),
#  ('From Dusk Till Dawn 2: Texas Blood Money', 0.1631752453068536),
#  ('Matilda: Special Edition', 0.16025398528165827),
#  ('Black Mask', 0.15770855377438045),
#  ('My Science Project', 0.1553083517130018),
#  ('Lord of Illusions', 0.15510517940087326),
#  ('13 Ghosts', 0.1543528320715826),
#  ('Heaven & Earth', 0.1540261600426514),
#  ('The Twilight Zone: Vol. 33', 0.14858829644108063),
#  ('The Brady Bunch Movie', 0.1474051617753891),
#  ('Rudolph the Red-Nosed Reindeer', 0.14668121447449856),
#  ('Earthsea', 0.14168215079434093),
#  ('Elephant', 0.1406936392076627),
#  ('Hysterical Blindness', 0.13886740135338524),
#  ('High Art', 0.13661899491910853),
#  ('A Nightmare on Elm Street 3: Dream Warriors', 0.1361995015503204),
#  ('Drop Dead Fred', 0.1361558061163467),
#  ('Les Miserables in Concert', 0.13229299431707955),
#  ('The Three Musketeers', 0.13161438864628255),
#  ('Stargate SG-1: Season 3', 0.13067787415689053),
#  ("I'm Not Scared", 0.1289014971356167),
#  ('Critters', 0.12853470417706972),
#  ('The Poseidon Adventure', 0.12584964475306262),
#  ('Mr. Show: Season 2', 0.121276122765324),
#  ('About Adam', 0.12094366426805916),
#  ('The Last Shot', 0.1196138025264918),
#  ('The Fighting Seabees', 0.11926889861232377),
#  ('Omen III: The Final Conflict', 0.11785438300576352),
#  ('Burnt by the Sun', 0.11765857014772219),
#  ('Xena: Warrior Princess: Season 3', 0.11353914683433944),
#  ('The Return of the Living Dead', 0.11342360616425827),
#  ('Crocodile Dundee 2', 0.11326768878631405),
#  ('A Home of Our Own', 0.10882503927363076),
#  ('The Twilight Zone: Vol. 19', 0.10625241563932648),
#  ('Top Secret!', 0.10436206709644022),
#  ('Star 80', 0.103824935875046),
#  ('Beloved', 0.10343305868591327),
#  ('Sea of Love', 0.10246287390803856),
#  ('Blame It on Rio', 0.10181144772453757),
#  ('Players Club', 0.1015989354516946),
#  ('Bringing Out the Dead', 0.09969045349222028),
#  ("VeggieTales Classics: Where's God When I'm Scared?", 0.09705174272193831),
#  ('Grateful Dawg', 0.09063023707716869),
#  ('Immortal Beloved', 0.08761038320833747),
#  ('Star Trek: Enterprise: Season 1', 0.08716117054197788),
#  ('Death Wish', 0.08613836368921086),
#  ('The Hole', 0.085490595605895),
#  ('The Twilight Zone: Vol. 39', 0.08354454371001095),
#  ('Zorro', 0.08200209719666303),
#  ('Highlander: Season 4', 0.0789770031598965),
#  ('I Want to Live!', 0.07859509437299719),
#  ('The Vikings', 0.07370436652543677),
#  ('The Desert Fox', 0.07101904923068705),
#  ('Simone', 0.07066463216838821),
#  ('Dragon Ball Z: Super Android 13', 0.06907626543792737),
#  ('Creepshow', 0.06829595358543913),
#  ('Return to Paradise', 0.06761279487748179),
#  ('Thief', 0.06661526255909835),
#  ('A Night at the Opera', 0.06407666036739172),
#  ('The Twilight Zone: Vol. 3', 0.06376193616279179),
#  ('My Favorite Wife', 0.05994140254794275),
#  ('The Trouble with Angels', 0.057457985962432345),
#  ('Species II', 0.057410408043723556),
#  ('Highway', 0.05732361597959172),
#  ('Everybody Loves Raymond: Season 3', 0.05713420245023476),
#  ('Amores Perros', 0.05614098727474529),
#  ('Jason Goes to Hell', 0.05421503081781348),
#  ('Good Guys Wear Black', 0.05419861419917693),
#  ('The Shop Around the Corner', 0.0520062601687181),
#  ("Todd McFarlane's Spawn", 0.05128490873533691),
#  ('Pretty Baby', 0.04695148290832089),
#  ('Le Divorce', 0.04686260544458927),
#  ('The Hustler', 0.045626991170384955),
#  ('Justice League: Justice on Trial', 0.04136865550230722),
#  ('Scratch', 0.041175960307032716),
#  ('Dolores Claiborne', 0.04108768754146142),
#  ('The 10th Kingdom', 0.03621786195959435),
#  ('The Last House on the Left', 0.03525488623149036),
#  ('Jane Eyre', 0.03478673763410237),
#  ("Ripley's Game", 0.032571845252312354),
#  ('The Invisible Circus', 0.03220486991087368),
#  ('Lies', 0.0320708913013675),
#  ('Life', 0.031489165969636204),
#  ('Switch', 0.029529148244776378),
#  ('The Lady Eve', 0.026360740508092624),
#  ('Batman Beyond: The Movie', 0.025977442220034105),
#  ('Aqua Teen Hunger Force: Vol. 1', 0.02152985215614945),
#  ('Tupac: Resurrection', 0.0208456925911209),
#  ('Live Flesh', 0.019982563194165765),
#  ('Stuart Little 2', 0.01988268516904456),
#  ('Existenz', 0.016858615906677633),
#  ("Mo' Money", 0.016075478142796737),
#  ('House of Cards Trilogy I: House of Cards', 0.016002195791043245),
#  ('The Scent of Green Papaya', 0.01461993808831642),
#  ('The Trouble With Harry', 0.012741783366934628),
#  ('Princess Mononoke', 0.009034544227810299),
#  ('Eddie and the Cruisers', 0.007519706501093784),
#  ('Get Real', 0.005786688974167104),
#  ('Saturday Night Live: The Best of Will Ferrell 2', 0.005408081312537832),
#  ('Never Die Alone', 0.005258055528514669),
#  ('Captain Pantoja and the Special Services', 0.0022332014029959996),
#  ('Owning Mahowny', -0.0008039931039307365),
#  ('The Kids in the Hall: Season 1', -0.0013659952714300274),
#  ('The Love Letter', -0.0018759216953189112),
#  ('The Truth About Charlie / Charade', -0.002132208182893369),
#  ('The Sandlot 2', -0.0031539772307769636),
#  ("Chappelle's Show: Season 1", -0.004152803290080286),
#  ('Frankie and Johnny', -0.009761471756627943),
#  ('The Adventures of Rocky and Bullwinkle', -0.011666426954893387),
#  ('The Hunger', -0.012022575080314204),
#  ('Ghosts of the Abyss', -0.01990602771327288),
#  ('Tampopo', -0.020420560117369573),
#  ('The Twilight Zone: Vol. 25', -0.021034256477212864),
#  ('Meet the Browns', -0.021831128684136586),
#  ('Little House on the Prairie: Season 2', -0.023506134730438416),
#  ('Control Room', -0.023506944434136253),
#  ('Birdy', -0.023769877204261398),
#  ('The Looney Tunes Golden Collection: Vol. 2', -0.026138611254407033),
#  ('The Taming of the Shrew', -0.026612300397134102),
#  ('Enduring Love', -0.036099981218918824),
#  ('Eat Drink Man Woman', -0.03695709039776697),
#  ('The Toxic Avenger', -0.03757569722656516),
#  ('Clockers', -0.03794993183663887),
#  ('The Impostors', -0.03880629922785474),
#  ('Breathless', -0.03883001712277125),
#  ('The Other Side of Heaven', -0.03920076554562877),
#  ('Married... with Children: The Most Outrageous Episodes: Vol. 2',
#   -0.04318186258871568),
#  ('The Rookie', -0.04610440097841162),
#  ('Man on the Train', -0.04725206843121495),
#  ('Teen Wolf / Teen Wolf Too (Double Feature)', -0.048592757866405885),
#  ('Babylon 5: Season 4', -0.051262770797798556),
#  ('The Man Who Cried', -0.051835673390909345),
#  ('Joe Kidd', -0.05367012977196183),
#  ('Quest for Fire', -0.0542210160704699),
#  ('To End All Wars', -0.05749487613269291),
#  ('Titanic', -0.05758445712982615),
#  ("Outfoxed: Rupert Murdoch's War on Journalism", -0.05784861989644332),
#  ('Ed Wood', -0.06002300327158819),
#  ('Everybody Loves Raymond: Season 1', -0.06466431175795631),
#  ("King's Ransom", -0.06533612478368594),
#  ('Great Balls of Fire!', -0.06851557924220494),
#  ('Cecil B. Demented', -0.06884772419253526),
#  ("Captain Corelli's Mandolin", -0.07049819626560268),
#  ('The Twilight Zone: Vol. 16', -0.07340868729714291),
#  ('Trainspotting', -0.07416114101644),
#  ("Summer of '42", -0.07484392861396681),
#  ('Mansfield Park', -0.07560720607682074),
#  ('Red Dwarf: Series 3', -0.08113034610980965),
#  ('In the Mood for Love', -0.08178888270306668),
#  ('Prime Suspect 1', -0.0840635153738017),
#  ('Death to Smoochy', -0.08472399409658313),
#  ('10', -0.08692149684971837),
#  ('Ravenous', -0.08731922563632731),
#  ('Ernest Goes to Jail', -0.08990717000085008),
#  ('Seems Like Old Times', -0.09023238040097827),
#  ('An Evening With Kevin Smith', -0.0902767437011386),
#  ('Mumford', -0.09127245406670492),
#  ('Cirque du Soleil: Varekai', -0.0922313690030804),
#  ("Dead Men Don't Wear Plaid", -0.09321957818546363),
#  ('Woman on Top', -0.09508300732147335),
#  ('Good Advice', -0.0955915885874515),
#  ('Concert for George', -0.0963544741435423),
#  ('Alias: Season 1', -0.09677479346196165),
#  ('King of the Hill: Season 1', -0.09755196451784351),
#  ('East/West', -0.09817634076045198),
#  ('Trekkies', -0.09882255918015936),
#  ('True Colors', -0.09922351275852968),
#  ("Blind Spot: Hitler's Secretary", -0.09955595870582697),
#  ('Hair', -0.0996163203099391),
#  ('Polyester', -0.10023189190986496),
#  ('Undercover Blues', -0.1009205412030518),
#  ('Small Time Crooks', -0.10147664383108244),
#  ('Sirens', -0.1020335263876521),
#  ('Polish Wedding', -0.10346459632989413),
#  ('Batman: The Animated Series: Tales of the Dark Knight',
#   -0.10439428903512252),
#  ('Half Past Dead', -0.10550289959702551),
#  ('The X-Files: Season 9', -0.10568622874788877),
#  ('Addicted to Love', -0.10714160182731461),
#  ('Stargate SG-1: Season 7', -0.10739370896770792),
#  ('VeggieTales: Dave and the Giant Pickle', -0.10955262571232954),
#  ('The Quest', -0.11303909742527109),
#  ('Geronimo: An American Legend', -0.11554527612676156),
#  ('Dungeons & Dragons', -0.11705815093074587),
#  ("Muriel's Wedding", -0.11795872431752671),
#  ('Farscape: The Peacekeeper Wars', -0.12033347963557736),
#  ('My Bodyguard', -0.1211043373241718),
#  ('Fahrenheit 451', -0.1221834933318464),
#  ('The Twilight Zone: Vol. 15', -0.12222691087063826),
#  ('Love in the Afternoon', -0.12269310698456204),
#  ('Funny Face', -0.1257417632123647),
#  ('The Prophecy 2', -0.12576196249805108),
#  ('Spider-Man: The New Animated Series: Season 1', -0.1272741274009203),
#  ('He Said', -0.1282701837470164),
#  ('Pelle the Conqueror', -0.131522196139406),
#  ('Exit to Eden', -0.13395600309626293),
#  ('Cowboys & Angels', -0.13452622305423576),
#  ('The Mists of Avalon', -0.13455530023056467),
#  ('Viva La Bam: Season 1', -0.1352673363992833),
#  ('Farscape: Season 2', -0.13899496853904672),
#  ('The Last American Virgin', -0.13954352480031418),
#  ('The Glass Menagerie', -0.13954756118158212),
#  ("Marvin's Room", -0.14003576637663145),
#  ('George Carlin: Complaints and Grievances', -0.14204858470019985),
#  ('Black Adder', -0.14378447889868987),
#  ('Judgment Day', -0.14426267864461653),
#  ('Bedazzled', -0.14770209224364617),
#  ('The Two Jakes', -0.14816721931626128),
#  ('Porn Star: The Legend of Ron Jeremy', -0.14856256213179803),
#  ...]

# %%
user_original_ratings = df.loc[user_id].values
user_original_ratings = df.loc[user_id].values

unrated_movies_with_predictions = [(movie, rating) for movie, rating in sorted_movies_with_predictions if user_original_ratings[movie_titles.index(movie)] == 0]

# %%
N = 10  # Number of top recommendations to extract
top_recommendations = unrated_movies_with_predictions[:N]

print(f"Top {N} movie recommendations for User ID {user_id}:")
for movie, predicted_rating in top_recommendations:
    print(f"Movie: {movie}, Predicted Rating: {predicted_rating:.2f}")
# Out:
# Top 10 movie recommendations for User ID 6:
# Movie: Beverly Hills Cop, Predicted Rating: 6.06
# Movie: Training Day, Predicted Rating: 5.58
# Movie: U.S. Marshals, Predicted Rating: 5.04
# Movie: Sixteen Candles, Predicted Rating: 5.00
# Movie: Chocolat, Predicted Rating: 4.94
# Movie: Joy Ride, Predicted Rating: 4.90
# Movie: Harold and Kumar Go to White Castle, Predicted Rating: 4.87
# Movie: Dawn of the Dead, Predicted Rating: 4.86
# Movie: The Missing, Predicted Rating: 4.84
# Movie: Shanghai Noon, Predicted Rating: 4.81
